# %% [markdown]
# > Angsuman Bhandary
# >
# > Computer Vision & Internet of Things Intern @ TSF GRIP AUGUST2021
# >
# > Task 1: Object Detection / Optical Character Recognition (ORC)
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [ ]:</p>
# </blockquote></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td></td>
# </tr>
# </tbody>
# </table></td>
# </tr>
# </tbody>
# </table>
#
# > Import Libraries
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [16]:</p>
# </blockquote></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p><strong>import</strong> cv2 <strong>as</strong> cv<br />
# <strong>import</strong> matplotlib.pyplot <strong>as</strong> plt<br />
# <strong>import</strong> pytesseract</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table></td>
# </tr>
# </tbody>
# </table>
#
# > Image
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [17]:</p>
# <p>Out[17]:</p>
# </blockquote></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>image<strong>=</strong>cv<strong>.</strong>imread("D:\\TSF\\OD.jpg")<br />
# plt<strong>.</strong>imshow(image)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
# <blockquote>
# <p>&lt;matplotlib.image.AxesImage at 0x220f7c6a400&gt;</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:76b6a98fe0944e1490369b55c86e962d/media/image1.png" style="width:3.61528in;height:2.6255in" />
# >
# > Convert image to grayscale
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [18]:</p>
# <p>Out[18]:</p>
# </blockquote></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>gray<strong>=</strong>cv<strong>.</strong>cvtColor(image,cv<strong>.</strong>COLOR_BGR2GRAY)<br />
# plt<strong>.</strong>imshow(gray)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
# <blockquote>
# <p>&lt;matplotlib.image.AxesImage at 0x220f7cd62e0&gt;</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:76b6a98fe0944e1490369b55c86e962d/media/image2.png" style="width:3.61528in;height:2.6255in" />
# >
# > To detect text
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [19]:</p>
# </blockquote></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>text<strong>=</strong>pytesseract<strong>.</strong>image_to_string(gray)<br />
# print(text)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table></td>
# </tr>
# </tbody>
# </table>
#
# > “The
# > purpose
# > of our lives
# > is to be
# >
# > happy’
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [ ]:</p>
# </blockquote></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td></td>
# </tr>
# </tbody>
# </table></td>
# </tr>
# </tbody>
# </table>
